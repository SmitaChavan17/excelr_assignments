# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
wt=pd.read_csv("E:\\DS_data\\Assignment\\wc-at.csv")

# %%
wt.head()
# Out:
#    Waist     AT
# 0  74.75  25.72
# 1  72.60  25.89
# 2  81.80  42.60
# 3  83.95  42.80
# 4  74.65  29.84

# %%
wt['Waist'].mean()
# Out:
# 91.90183486238531

# %%
wt['Waist'].median()
# Out:
# 90.8

# %%
wt['Waist'].mode()
# Out:
# 0     94.5
# 1    106.0
# 2    108.5
# Name: Waist, dtype: float64

# %%
wt['Waist'].hist()
# Out:
# <Axes: >

# %%
sns.distplot(wt['Waist'])
plt.grid(True)
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_8816\2821167559.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(wt['Waist'])

# %%
wt['Waist'].skew()
# Out:
# 0.1340560824786468

# %%
# mean> median, right whisker is larger than left whisker, data is positively skewed.

# %%
wt['Waist'].kurt()
# Out:
# -1.1026666011768886
